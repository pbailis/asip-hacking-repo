# %%
# %pylab inline
import pickle, mpld3
import pandas as pd
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
mpld3.enable_notebook(local=True)
pylab.rcParams['savefig.dpi'] = 200 
pylab.rcParams['figure.figsize'] = (10.0, 5.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # August 03 Results Synthetic

# %% [markdown]
# Settings:
#
# ```python
# def describe_point_cloud(pointsPerPartition = 1000000,
#                          partitionSkew = 0.1,
#                          labelNoise = 0.1,
#                          dimension = 10):
#     return   "--pointCloudPointsPerPartition %d " \
#              "--pointCloudPartitionSkew %f " \
#              "--pointCloudLabelNoise %f " \
#              "--pointCloudDimension %d " % \
#              (pointsPerPartition,
#               partitionSkew,
#               labelNoise,
#               dimension)
#
# def make_run_cmd(algorithm,
#                  datasetConfigName,
#                  datasetConfigStr,
#                  regType="L2",
#                  regParam=0.0001,
#                  numPartitions = 40,
#                  iterationStart = 1,
#                  iterationEnd = 100,
#                  iterationStep = 2,
#                  miscStr = ""):
#     return "cd ~/spark; sbin/stop-all.sh; sleep 5; sbin/start-all.sh;" \
#            "./bin/spark-submit " \
#            "--class org.apache.spark.examples.mllib.research.SynchronousADMMTests" \
#            " examples/target/scala-*/spark-examples-*.jar " \
#            "--algorithm %s " \
#            "--regType %s " \
#            "--regParam %f " \
#            "--format %s " \
#            "--numPartitions %d " \
#            "--sweepIterationStart %d " \
#            "--sweepIterationEnd %d " \
#            " --sweepIterationStep %d " \
#            " %s %s " % \
#             (algorithm,
#              regType,
#              regParam,
#              datasetConfigName,
#              numPartitions,
#              iterationStart,
#              iterationEnd,
#              iterationStep,
#              datasetConfigStr,
#              miscStr)
#
# ```

# %%
results = pickle.load(open("08_03_14.pkl"))
df = pd.DataFrame.from_dict(results)

# %%
fig, ax = plt.subplots()
ax.set_yscale('log')
yval = 'training_loss'
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMMAsync'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMMAsync'], 'g-x')
ax.set_title(yval, size=18)
mpld3.display(fig, local=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el7325444526004643442142244"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el7325444526004643442142244", {"axes": [{"xlim": [0.0, 120000.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "training_loss", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 18.0, "position": [0.5, 1.0179211469534051], "rotation": -0.0, "id": "el732544462774608"}], "zoomable": true, "images": [], "xdomain": [0.0, 120000.0], "ylim": [1000000.0, 1000000000.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "log", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el732544452904912"}, {"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data02", "id": "el732544462774224"}, {"color": "#007F00", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data03", "id": "el732544452949456"}], "markers": [{"edgecolor": "#0000FF", "facecolor": "#0000FF", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, -3.0], [-3.0, -3.0], [3.0, 3.0]], ["M", "L", "M", "L"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el732544452904912pts"}, {"edgecolor": "#FF0000", "facecolor": "#FF0000", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, -3.0], [-3.0, -3.0], [3.0, 3.0]], ["M", "L", "M", "L"]], "alpha": 1, "xindex": 0, "data": "data02", "id": "el732544462774224pts"}, {"edgecolor": "#007F00", "facecolor": "#007F00", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[-3.0, 3.0], [3.0, -3.0], [-3.0, -3.0], [3.0, 3.0]], ["M", "L", "M", "L"]], "alpha": 1, "xindex": 0, "data": "data03", "id": "el732544452949456pts"}], "id": "el732544452614352", "ydomain": [1000000.0, 1000000000.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 400.0, "width": 800.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "data": {"data02": [[6324.0, 40000000.0], [8057.0, 12226793.50592563], [7531.0, 9246015.66715715], [8638.0, 9150499.053622432], [12459.0, 9095716.769658983], [13492.0, 9083502.231688635], [14830.0, 9082517.892638467], [15778.0, 9081774.087860959], [15519.0, 9081898.671114272], [18680.0, 9082447.93768701], [18232.0, 9080053.628773615], [19557.0, 9079468.955891998], [23030.0, 9078826.097453509], [20440.0, 9078844.19579012], [22353.0, 9078315.849262245], [24181.0, 9077677.542043641], [25182.0, 9076702.403903864], [25983.0, 9076929.314129692], [30243.0, 9076706.009900276], [28523.0, 9076332.552198019], [30165.0, 9075908.052398112], [30744.0, 9075665.723321924], [32955.0, 9075618.067283206], [33488.0, 9075369.12408373], [35400.0, 9075464.334892763], [36925.0, 9075256.44447911], [37247.0, 9074694.50930466], [38794.0, 9074858.616325827], [41083.0, 9074941.880539268], [40911.0, 9074838.34044998], [42629.0, 9074771.628689744], [43550.0, 9074655.270397669], [45802.0, 9074525.237499619], [47538.0, 9074615.001044458], [48773.0, 9074358.922464635], [48827.0, 9074404.768911451], [50282.0, 9074369.620752908], [52806.0, 9074365.794972679], [52474.0, 9074362.065954654], [53392.0, 9074383.01210904], [55813.0, 9074417.084471297], [57815.0, 9074473.482274255], [66763.0, 9074390.899407934], [60989.0, 9074332.295127975], [62843.0, 9074335.402379343], [63680.0, 9074326.696484849], [65589.0, 9074331.455410745], [6628 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "/nbextensions/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("/nbextensions/mpld3.v0.2.js", function(){
#
#          mpld3.draw_fi

# %%
fig, ax = plt.subplots()
#ax.set_yscale('log')
yval = 'training_error'
ax.set_yscale('log')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMMAsync'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMMAsync'], 'g-x')
ax.set_title(yval, size=18)
mpld3.display(fig, local=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el7325444518999205806032604"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el7325444518999205806032604", {"axes": [{"xlim": [0.0, 120000.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "training_error", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize":