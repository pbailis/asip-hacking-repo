# %%
# %pylab inline
import pickle, mpld3
import pandas as pd
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
mpld3.enable_notebook(local=True)
pylab.rcParams['savefig.dpi'] = 200 
pylab.rcParams['figure.figsize'] = (10.0, 5.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # August 03 Results Synthetic

# %% [markdown]
# Settings:
#
# ```python
# def describe_point_cloud(pointsPerPartition = 1000000,
#                          partitionSkew = 0.1,
#                          labelNoise = 0.1,
#                          dimension = 10):
#     return   "--pointCloudPointsPerPartition %d " \
#              "--pointCloudPartitionSkew %f " \
#              "--pointCloudLabelNoise %f " \
#              "--pointCloudDimension %d " % \
#              (pointsPerPartition,
#               partitionSkew,
#               labelNoise,
#               dimension)
#
# def make_run_cmd(algorithm,
#                  datasetConfigName,
#                  datasetConfigStr,
#                  regType="L2",
#                  regParam=0.0001,
#                  numPartitions = 40,
#                  iterationStart = 1,
#                  iterationEnd = 100,
#                  iterationStep = 2,
#                  miscStr = ""):
#     return "cd ~/spark; sbin/stop-all.sh; sleep 5; sbin/start-all.sh;" \
#            "./bin/spark-submit " \
#            "--class org.apache.spark.examples.mllib.research.SynchronousADMMTests" \
#            " examples/target/scala-*/spark-examples-*.jar " \
#            "--algorithm %s " \
#            "--regType %s " \
#            "--regParam %f " \
#            "--format %s " \
#            "--numPartitions %d " \
#            "--sweepIterationStart %d " \
#            "--sweepIterationEnd %d " \
#            " --sweepIterationStep %d " \
#            " %s %s " % \
#             (algorithm,
#              regType,
#              regParam,
#              datasetConfigName,
#              numPartitions,
#              iterationStart,
#              iterationEnd,
#              iterationStep,
#              datasetConfigStr,
#              miscStr)
#
# ```

# %%
results = pickle.load(open("08_03_14.pkl"))
df = pd.DataFrame.from_dict(results)

# %%
fig, ax = plt.subplots()
ax.set_yscale('log')
yval = 'training_loss'
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMMAsync'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMMAsync'], 'g-x')
ax.set_title(yval, size=18)
mpld3.display(fig, local=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el8071444603549602575397167"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
fig, ax = plt.subplots()
#ax.set_yscale('log')
yval = 'training_error'
ax.set_yscale('log')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMMAsync'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMMAsync'], 'g-x')
ax.set_title(yval, size=18)
mpld3.display(fig, local=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el8071444641159844115246946"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %% [markdown]
# # Run 2nd Round of Experiments

# %%
results = pickle.load(open("08_03_14_dim100.pkl"))
df = pd.DataFrame.from_dict(results)

# %%
fig, ax = plt.subplots()
ax.set_yscale('log')
yval = 'training_loss'
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMMAsync'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMMAsync'], 'g-x')
ax.set_title(yval, size=18)
mpld3.display(fig, local=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el8071444645274402113954607"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
fig, ax = plt.subplots()
ax.set_yscale('log')
yval = 'training_error'
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMMAsync'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMMAsync'], 'g-x')
ax.set_title(yval, size=18)
mpld3.display(fig, local=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el8071444645280169516404361"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %% [markdown]
# # Run 2nd Round of Experiments

# %%
results = pickle.load(open("08_03_14_dim100_4.pkl"))
df = pd.DataFrame.from_dict(results)
df
# Out:
#        algorithm                                            command  \
# 0            SVM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 1        SVMADMM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 2   SVMADMMAsync  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 3            SVM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 4        SVMADMM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 5   SVMADMMAsync  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 6            SVM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 7        SVMADMM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 8   SVMADMMAsync  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 9            SVM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 10       SVMADMM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 11  SVMADMMAsync  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# 12           SVM  cd /mnt/spark; sbin/stop-all.sh; sleep 5; sbin...
# ...

# %%
[d['model'] for d in results if d['algorithm'] == 'SVM']
# Out:
# ['NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN',
#  'NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN',
# ...

# %%
fig, ax = plt.subplots()
ax.set_yscale('log')
yval = 'training_loss'
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMMAsync'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMMAsync'], 'g-x')
ax.set_title(yval, size=18)
mpld3.display(fig, local=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-34588bc6c55c> in <module>()
#       3 yval = 'training_loss'
#       4 ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'],
# ----> 5      [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
#       6 ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'],
#       7      [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4139             lines.append(line)
#    4140
# -> 4141         self.autoscale_view(scalex=scalex, scaley=scaley)
#    4142         return lines
#    4143
#
# ...

# %%
fig, ax = plt.subplots()
ax.set_yscale('log')
yval = 'training_error'
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVM'], 'b-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMM'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMM'], 'r-x')
ax.plot([d['runtime_ms'] for d in results if d['algorithm'] == 'SVMADMMAsync'], 
     [d[yval] for d in results if d['algorithm'] == 'SVMADMMAsync'], 'g-x')
ax.set_title(yval, size=18)
mpld3.display(fig, local=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el807144464830480464396663"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...
